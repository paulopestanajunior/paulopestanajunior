# %%
import nest_asyncio
nest_asyncio.apply()
WORKDIR = 'C:/Users/Paulo/Desktop/infnet-projeto-final/mit_data_science/'

notebooks = [
    'Code/DataPrep/data_collection_yellow.ipynb',
    'Code/DataPrep/data_prep_yellow.ipynb',
    'Code/Analysis/feature_analysis_yellow.ipynb',
    'Code/Model/modeling.ipynb',
]

# %%
# %store WORKDIR

error_list = {}
for fname in notebooks:
    print('Notebook:', fname)
    notebook_path = WORKDIR + fname
    try:
        # %run $notebook_path
    except Exception as err:
        print('ERROR: ', err)
        error_list[fname] = err.__str__()
        break
# Out:
# Stored 'WORKDIR' (str)
# Notebook: Code/DataPrep/data_collection_yellow.ipynb
# Notebook: Code/DataPrep/data_prep_yellow.ipynb
# shape: (8000, 10)
# columns: Index(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude',
#        'fare_amount', 'passenger_count', 'pickup_datetime', 'pickup_latitude',
#        'pickup_longitude', 'tpep_dropoff_datetime', 'tpep_pickup_datetime'],
#       dtype='object')
# True     5879
# False    2121
# Name: pickup_longitude, dtype: int64
#  True     0.734875
# False    0.265125
# Name: pickup_longitude, dtype: float64
# True     5879
# False    2121
# Name: pickup_latitude, dtype: int64
#  True     0.734875
# False    0.265125
# Name: pickup_latitude, dtype: float64
# True     5882
# False    2118
# Name: dropoff_longitude, dtype: int64
#  True     0.73525
# False    0.26475
# Name: dropoff_longitude, dtype: float64
# True     5882
# False    2118
# Name: dropoff_latitude, dtype: int64
#  True     0.73525
# False    0.26475
# ...
